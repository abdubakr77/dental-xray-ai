# %%
import yaml
from ultralytics import YOLO

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
config = {
    'epochs': 100,
    'save': True,
    'imgsz': 768, 
    'batch': 16,         
    'patience': 20,
    'optimizer': 'AdamW',
    'lr0': 0.001,
    'lrf': 0.01,
    'project': 'runs',
    'plots': True,
    'verbose': True,
    'device': 'cuda',
    'workers': 4,
    'auto_augment': None,
    # 'albumentations':None
}
